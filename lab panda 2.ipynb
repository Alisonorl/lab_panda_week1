# %%
import pandas as pd

# %%
df1 = pd.read_csv('marketing_customer_analysis.csv')
df1


df1.columns = df1.columns.str.lower()
df1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
df1[df1.isna()]
# Out:
#        unnamed: 0 customer state  customer lifetime value response coverage  \
# 0             NaN      NaN   NaN                      NaN      NaN      NaN
# 1             NaN      NaN   NaN                      NaN      NaN      NaN
# 2             NaN      NaN   NaN                      NaN      NaN      NaN
# 3             NaN      NaN   NaN                      NaN      NaN      NaN
# 4             NaN      NaN   NaN                      NaN      NaN      NaN
# ...           ...      ...   ...                      ...      ...      ...
# 10905         NaN      NaN   NaN                      NaN      NaN      NaN
# 10906         NaN      NaN   NaN                      NaN      NaN      NaN
# 10907         NaN      NaN   NaN                      NaN      NaN      NaN
# 10908         NaN      NaN   NaN                      NaN      NaN      NaN
# 10909         NaN      NaN   NaN                      NaN      NaN      NaN
#
# ...

# %%
df1=df1.fillna(0)
df1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877           0              6857.519928        0
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
month = []
df1['effective to date'] = pd.to_datetime(df1['effective to date'])
df1['effective to date']
# Out:
# 0       2011-02-18
# 1       2011-01-18
# 2       2011-02-10
# 3       2011-01-11
# 4       2011-01-17
#            ...
# 10905   2011-01-19
# 10906   2011-01-06
# 10907   2011-02-06
# 10908   2011-02-13
# 10909   2011-01-08
# Name: effective to date, Length: 10910, dtype: datetime64[ns]

# %%
month = pd.DatetimeIndex(df1['effective to date']).month
month
# Out:
# Int64Index([2, 1, 2, 1, 1, 2, 2, 2, 1, 1,
#             ...
#             2, 1, 1, 1, 2, 1, 1, 2, 2, 1],
#            dtype='int64', name='effective to date', length=10910)

# %%
df1['month'] = month
df1
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877           0              6857.519928        0
#
#        coverage education effective to date employmentstatus gender  ...  \
# ...

# %%
df1[ df1['month'] <=1 ]
# Out:
#        unnamed: 0 customer       state  customer lifetime value response  \
# 1               1  KX64629  California              2228.525238       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# 8               8  FM55990  California              5989.773931      Yes
# 9               9  QX31376      Oregon             17114.328150       No
# ...           ...      ...         ...                      ...      ...
# 10902       10902  PP30874  California              3579.023825       No
# 10903       10903  SU71163     Arizona              2771.663013       No
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10909       10909  IV32877           0              6857.519928        0
#
#        coverage             education effective to date employmentstatus  \
# ...
